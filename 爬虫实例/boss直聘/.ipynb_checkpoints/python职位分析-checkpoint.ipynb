# %% [markdown]
# # python开发岗位需求分析

# %% [markdown]
# ## 1.导入模块

# %%
import pandas as pd
from pyecharts.charts import *
from pyecharts import options as opts

# %% [markdown]
# ## 2.导入数据

# %%
boss = pd.read_csv('boss.csv', engine='python', encoding='utf-8')

# %%
boss.head()
# Out:
#               职位名称        职位地址          薪资    学历经验要求       公司名称  \
# 0     Python 爬虫工程师   北京·海淀区·上地      20-40K  3-5年学历不限       墨云科技
# 1  底薪20K 双休 python  北京·海淀区·五道口      20-21K    3-5年大专       惠承科技
# 2     Python 开发工程师  北京·海淀区·西二旗  18-35K·14薪   5-10年本科  星云Clustar
# 3   Python 后端开发工程师   北京·朝阳区·望京      15-25K  经验不限学历不限     北京知道创宇
# 4     Python 开发工程师   北京·朝阳区·国贸  15-22K·14薪    3-5年本科       先胜业财
#
#                公司信息                                               公司福利  \
# 0    信息安全B轮100-499人         零食下午茶，餐补，定期体检，节日福利，年终奖，加班补助，五险一金，带薪年假，股票期权
# 1      企业服务100-499人            年终奖，员工旅游，五险一金，节日福利，零食下午茶，定期体检，带薪年假，交通补助
# 2     互联网B轮100-499人  交通补助，定期体检，餐补，年终奖，节日福利，零食下午茶，带薪年假，补充医疗保险，五险一金，股...
# 3  信息安全C轮1000-9999人  春节假期，通讯补贴，全勤奖，八险一金，年终奖，零食下午茶，补充医疗保险，节日福利，员工旅游，...
# 4    企业服务C轮100-499人  带薪年假，年终奖，节日福利，加班补助，股票期权，零食下午茶，通讯补贴，五险一金，定期体检，员工旅游
#
#                                                详情页链接
# 0  https://www.zhipin.com/job_detail/3dd042791ae5...
# 1  https://www.zhipin.com/job_detail/b845e2156d7e...
# 2  https://www.zhipin.com/job_detail/43f73681f832...
# 3  https://www.zhipin.com/job_detail/f7fe4279d46a...
# 4  https://www.zhipin.com/job_detail/d8dcf215a266...

# %%
boss.shape
# Out:
# (2325, 8)

# %% [markdown]
# ## 3.数据处理

# %% [markdown]
# ### 3.1 查看重复值

# %%
boss.duplicated().sum()
# Out:
# 17

# %%
boss.drop_duplicates(inplace=True)

# %%
boss.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3.2 查看缺失值

# %%
boss.isnull().sum()
# Out:
# 职位名称        0
# 职位地址        0
# 薪资          0
# 学历经验要求      0
# 公司名称        0
# 公司信息        0
# 公司福利      241
# 详情页链接       0
# dtype: int64

# %% [markdown]
# ### 3.3 缺失值处理

# %%
boss['公司福利'].fillna('无', inplace=True)

# %%
boss.isnull().sum()
# Out:
# 职位名称      0
# 职位地址      0
# 薪资        0
# 学历经验要求    0
# 公司名称      0
# 公司信息      0
# 公司福利      0
# 详情页链接     0
# dtype: int64

# %% [markdown]
# ### 3.4 地区列处理

# %%
boss['职位地址'].unique()
# Out:
# array(['北京·海淀区·上地', '北京·海淀区·五道口', '北京·海淀区·西二旗', '北京·朝阳区·望京', '北京·朝阳区·国贸',
#        '北京·石景山区·鲁谷', '北京·海淀区·西北旺', '北京·朝阳区·三元桥', '北京·东城区·建国门内',
#        '北京·丰台区·马家堡', '北京·朝阳区·建国门', '北京·昌平区·沙河', '北京·房山区·长阳', '北京·朝阳区·立水桥',
#        '北京·大兴区·亦庄', '北京·海淀区·蓟门桥', '北京·海淀区·牡丹园', '北京·丰台区·科技园区',
#        '北京·东城区·王府井', '北京·朝阳区·安贞', '北京·怀柔区·雁栖', '北京·海淀区·清河', '北京·海淀区·颐和园',
#        '北京', '北京·朝阳区·百子湾', '北京·朝阳区·红庙', '北京·朝阳区·团结湖', '北京·石景山区·苹果园',
#        '北京·朝阳区·酒仙桥', '北京·海淀区·知春路', '北京·海淀区·中关村', '北京·丰台区·广安门',
#        '北京·昌平区·回龙观', '北京·海淀区·西山', '北京·朝阳区·鸟巢', '北京·丰台区·丽泽', '北京·西城区·西单',
#        '北京·朝阳区·大望路', '北京·西城区·德外大街', '北京·海淀区·马连洼', '北京·朝阳区·来广营',
#        '北京·西城区·大栅栏', '北京·东城区·东四', '北京·朝阳区·三里屯', '北京·朝阳区·798',
#        '北京·海淀区·双榆树', '北京·朝阳区·朝外', '北京·朝阳区·祁家豁子', '北京·海淀区·四季青',
#        '北京·海淀区·五路居', '北京·朝阳区·亚运村', '北京·海淀区·人民大学', '北京·昌平区·西三旗',
#        '北京·海淀区·北太平庄', '北京·西城区·西直门', '北京·西城区·金融街', '北京·海淀区·公主坟',
#        '北京·通州区·梨园', '北京·朝阳区·朝阳门', '北京·朝阳区·建外', '北京·西城区·宣武门', '北京·西城区·右安门',
#        '北京·海淀区·西直门', '北京·朝阳区·姚家园', '北京·朝阳区·双井', '北京·朝阳区·安定门',
#        '北京·海淀区·魏公村', '北京·东城区·前门', '北京·朝阳区·燕莎', '北京·朝阳区·石佛营', '北京·西城区·月坛',
#        '北京·朝阳区·常营', '北京·朝阳区·四惠东', '深圳·福田区·会展中心', '深圳·宝安区·西乡',
#        '深圳·南山区·科技园', '深圳·福田区·岗厦', '深圳·龙岗区·坂田', '深圳·宝安区·福永', '深圳·福田区·景田',
#        '深圳·宝安区·宝安中心区', '深圳·福田区·购物公园', '深圳·福田区·车公庙', '深圳·福田区·新洲',
#        '深圳·宝安区·新安', '深圳·南山区·西丽', '深圳·宝安区·石岩', '深圳·南山区·前海', '深圳·南山区·华侨城',
#        '深圳·罗湖区·笋岗', '深圳', '深圳·南山区·海岸城', '深圳·福田区·福田保税区', '深圳·龙岗区·布吉',
#        '深圳·罗湖区·东门', '深圳·龙岗区·华为坂田基地', '深圳·罗湖区·地王', '深圳·福田区·华强南',
#        '深圳·宝安区·翻身', '深圳·龙华区·民治', '深圳·龙华区·龙华', '深圳·宝安区·沙井', '深圳·南山区·大学城',
#        '深圳·罗湖区·莲塘', '深圳·南山区·南头', '深圳·南山区·南油', '深圳·南山区·后海', '深圳·福田区·园岭',
#        '深圳·龙岗区·双龙', '深圳·福田区·福田中心', '深圳·光明区·光明', '深圳·龙岗区·岗头', '深圳·龙岗区·平湖',
#        '深圳·福田区·皇岗', '深圳·南山区·蛇口', '深圳·坪山区·坪山', '深圳·龙华区·清湖', '深圳·罗湖区·国贸',
#        '深圳·南山区·深圳湾', '深圳·福田区·华强北', '深圳·南山区·白石洲', '深圳·龙华区·观澜',
#        '深圳·福田区·香蜜湖', '深圳·福田区·沙尾', '深圳·罗湖区·园岭', '深圳·福田区·竹子林', '上海',
#        '上海·静安区·静安寺', '上海·杨浦区·东外滩', '上海·静安区·汶水路', '上海·虹口区·曲阳',
#        '上海·杨浦区·五角场', '上海·浦东新区·张江', '上海·静安区·火车站', '上海·徐汇区·田林',
#        '上海·浦东新区·金桥', '上海·闵行区·浦江', '上海·闵行区·春申', '上海·长宁区·北新泾',
#        '上海·浦东新区·世纪公园', '上海·浦东新区·周浦', '上海·杨浦区·新江湾城', '上海·松江区·佘山',
#        '上海·浦东新区·陆家嘴', '上海·浦东新区·迪士尼', '上海·闵行区·莘庄', '上海·徐汇区·漕河泾',
#        '上海·徐汇区·龙华', '上海·闵行区·虹梅路', '上海·闵行区·吴泾', '上海·普陀区·长征', '上海·闵行区·华漕',
#        '上海·徐汇区·徐家汇', '上海·青浦区·赵巷', '上海·闵行区·七宝', '上海·松江区·松江大学城',
#        '上海·普陀区·长风', '上海·浦东新区·塘桥', '上海·松江区·莘闵别墅', '上海·闵行区·老闵行',
#        '上海·静安区·大宁', '上海·黄浦区·西藏南路', '上海·松江区·松江工业区', '上海·嘉定区·江桥',
#        '上海·浦东新区·南码头', '上海·浦东新区·联洋', '上海·虹口区·四川北路', '上海·浦东新区·洋泾',
#        '上海·黄浦区·老西门', '上海·长宁区·新华路', '上海·闵行区·虹桥', '上海·浦东新区·三林', '上海·徐汇区·岳阳',
#        '上海·普陀区·武宁', '上海·黄浦区·城隍庙', '上海·嘉定区·嘉定镇', '上海·虹口区·周家嘴路',
#        '上海·浦东新区·康桥', '上海·浦东新区·花木', '上海·浦东新区·新场', '上海·长宁区·仙霞', '上海·杨浦区·中原',
#        '上海·长宁区·中山公园', '上海·浦东新区·临港', '上海·松江区·九亭', '上海·静安区·南京西路',
#        '上海·闵行区·合川路', '上海·闵行区·颛桥', '上海·宝山区·上海大学', '上海·长宁区·古北',
#        '上海·黄浦区·新天地', '上海·虹口区·江湾', '上海·杨浦区·长阳路', '上海·嘉定区·南翔',
#        '上海·浦东新区·八佰伴', '上海·奉贤区·南桥', '上海·黄浦区·人民广场', '上海·静安区·彭浦镇',
#        '上海·黄浦区·五里桥', '上海·浦东新区·北蔡', '广州·天河区·天河北', '广州·天河区·员村',
#        '广州·黄埔区·科学城', '广州·海珠区·琶洲', '广州', '广州·番禺区·市桥', '广州·番禺区·番禺广场',
#        '广州·天河区·珠江新城', '广州·番禺区·大学城', '广州·越秀区·东风东', '广州·天河区·龙洞',
#        '广州·天河区·车陂', '广州·天河区·小新塘', '广州·海珠区·工业大道', '广州·天河区·猎德', '广州·天河区·高唐',
#        '广州·番禺区·长隆', '广州·天河区·跑马场', '广州·天河区·岗顶', '广州·黄埔区·萝岗高德汇',
#        '广州·白云区·同德', '广州·花都区·莲塘', '广州·天河区·五山', '广州·荔湾区·西关', '广州·天河区·东圃',
#        '广州·天河区·龙口', '广州·海珠区·江南大道', '广州·天河区·棠下', '广州·白云区·白云大道',
#        '广州·南沙区·榄核', '广州·天河区·华景新城', '广州·番禺区·新造', '广州·越秀区·中山六路',
#        '广州·海珠区·赤岗', '广州·天河区·天河公园', '广州·天河区·黄村', '广州·黄埔区·高唐', '广州·番禺区·南村',
#        '广州·增城区·新塘广场', '广州·花都区·花山', '广州·黄埔区·中心城', '广州·番禺区·南浦', '广州·黄埔区·东圃',
#        '广州·番禺区·华南', '广州·天河区·岑村', '广州·番禺区·洛溪', '广州·天河区·天河客运站',
#        '广州·越秀区·北京路', '广州·越秀区·沿江路', '广州·白云区·金沙洲', '广州·越秀区·五羊新城',
#        '广州·天河区·燕岭', '广州·番禺区·厦滘', '广州·越秀区·东风中路', '广州·白云区·元岗', '广州·海珠区·东晓',
#        '广州·越秀区·越秀公园', '广州·白云区·新市', '广州·黄埔区·万达广场', '广州·南沙区·横沥',
#        '广州·越秀区·中华广场', '广州·天河区·元岗', '广州·天河区·时尚天河', '广州·南沙区·黄阁',
#        '广州·荔湾区·陈家祠', '广州·海珠区·客村', '广州·番禺区·广州南站', '广州·天河区·柯木塱村',
#        '广州·番禺区·石基', '广州·海珠区·新港西路沿线', '广州·天河区·体育中心', '广州·越秀区·淘金',
#        '广州·越秀区·环市东', '广州·天河区·冼村', '广州·黄埔区', '广州·越秀区·区庄', '广州·白云区·石井',
#        '广州·白云区·罗冲围', '杭州·滨江区·滨江区政府', '杭州·滨江区·长河', '杭州·余杭区·五常', '杭州',
#        '杭州·西湖区·黄龙', '杭州·余杭区·仓前', '杭州·西湖区·翠苑', '杭州·萧山区·北干', '杭州·西湖区·转塘',
#        '杭州·滨江区·浦沿', '杭州·西湖区·古荡', '杭州·萧山区·奥体中心', '杭州·西湖区·高新文教区',
#        '杭州·西湖区·留下', '杭州·富阳区', '杭州·滨江区·西兴', '杭州·西湖区·西溪', '杭州·萧山区·宁围',
#        '杭州·拱墅区·上塘', '杭州·萧山区·钱江世纪城', '杭州·临平区·塘栖', '杭州·拱墅区·蓝钻天城购物中心',
#        '杭州·拱墅区·拱宸桥', '杭州·拱墅区·万达广场', '杭州·萧山区·萧山经济开发区', '杭州·西湖区·文新',
#        '杭州·西湖区·文一路', '杭州·上城区·钱江新城', '杭州·余杭区·未来科技城', '杭州·西湖区·文三路',
#        '杭州·钱塘区·下沙', '杭州·上城区·三堡', '杭州·余杭区·万达广场', '杭州·余杭区·海创园', '杭州·西湖区·三墩',
#        '杭州·钱塘区·白杨', '杭州·临平区·临平', '杭州·上城区·火车东站', '杭州·西湖区·文二路', '杭州·西湖区·西湖',
#        '天津·红桥区·水游城', '天津·和平区·劝业场', '天津·河西区·大营门', '天津', '天津·西青区·侯台',
#        '天津·东丽区·东丽开发区', '天津·河东区·富民路', '天津·南开区·时代奥城', '天津·西青区·大学城',
#        '天津·河东区·上杭路', '天津·河东区·天津站', '天津·和平区·南市', '天津·津南区·八里台', '天津·津南区·双港',
#        '天津·东丽区·军粮城', '天津·河东区·大王庄', '天津·西青区·张家窝', '天津·河西区·梅江',
#        '天津·武清区·下朱庄', '天津·滨海新区·工农村', '天津·河西区·佟楼', '天津·河西区·土城',
#        '天津·南开区·风荷园', '天津·南开区·白堤路', '天津·河东区·中山门', '天津·西青区·大寺', '天津·南开区·鼓楼',
#        '天津·北辰区·北仓', '天津·滨海新区·中新生态城', '天津·河东区·向阳楼', '天津·南开区·水上',
#        '天津·河北区·民权门', '天津·西青区·中北', '天津·南开区·南开大学', '天津·西青区·李七庄',
#        '天津·滨海新区·泰达MSD', '天津·滨海新区·新河街', '天津·滨海新区·开发区', '天津·和平区·小白楼',
#        '天津·滨海新区·响螺湾商圈', '天津·东丽区·华明', '天津·武清区·徐官屯', '天津·宝坻区·城关',
#        '天津·河东区·大直沽', '天津·武清区·保利', '天津·和平区·滨江道', '天津·南开区·兴南街',
#        '天津·西青区·西青大学城', '天津·红桥区·邵公庄', '天津·南开区·天拖', '天津·南开区·长虹公园',
#        '天津·河北区·建昌道', '天津·北辰区·双口', '天津·红桥区·西沽', '天津·南开区·西南角', '天津·津南区·咸水沽',
#        '天津·武清区·运河西', '天津·南开区·体育中心街', '天津·和平区·和平路', '天津·红桥区·芥园道',
#        '天津·武清区·佛罗伦萨', '天津·武清区·泉州北路', '天津·南开区·向阳路', '天津·东丽区·空港',
#        '天津·武清区·北郑', '天津·滨海新区', '天津·南开区·海光寺', '天津·南开区·黄河道', '天津·西青区·会展中心',
#        '天津·滨海新区·经济开发区', '天津·河北区·火车站', '天津·南开区·王顶堤', '天津·河西区·马场街',
#        '天津·河西区·尖山', '天津·河西区·下瓦房', '天津·南开区·华苑', '天津·河东区·大桥道',
#        '天津·和平区·鞍山道沿线', '天津·武清区', '西安·雁塔区·高新软件园', '西安·雁塔区·枫林绿洲',
#        '西安·雁塔区·绿地世纪城', '西安·未央区·未央路沿线', '西安', '西安·雁塔区·电子城', '西安·未央区·三桥',
#        '西安·雁塔区·丈八', '西安·雁塔区', '西安·长安区·王寺', '西安·新城区·钟楼', '西安·长安区·航天城',
#        '西安·雁塔区·高新路', '西安·碑林区·文艺路', '西安·雁塔区·曲江新区', '西安·雁塔区·紫薇田园都市',
#        '西安·雁塔区·雁翔路', '西安·雁塔区·鱼化寨', '西安·灞桥区·浐灞半岛', '西安·雁塔区·明德门',
#        '西安·新城区·火车站', '西安·长安区·秦岭沿线', '西安·未央区·经济技术开发区', '西安·长安区·紫薇田园都市',
#        '西安·雁塔区·太白南路沿线', '西安·莲湖区·红庙坡', '西安·雁塔区·科技路西口', '西安·长安区·高新软件园',
#        '厦门', '厦门·湖里区·禾山', '厦门·集美区·灌口', '厦门·思明区·软件园', '厦门·思明区·莲花',
#        '厦门·湖里区·五缘湾', '厦门·集美区·杏林', '厦门·同安区·后田海鲜船坞', '厦门·集美区·后溪',
#        '厦门·湖里区·湖里大道', '厦门·思明区·禾祥西路', '厦门·湖里区·枋湖', '厦门·思明区', '厦门·思明区·观音山',
#        '厦门·湖里区·翔鹭', '厦门·思明区·文灶', '厦门·湖里区·万达广场', '厦门·思明区·火车站',
#        '厦门·湖里区·大唐世家', '厦门·思明区·曾厝垵', '厦门·集美区·集美新城', '厦门·集美区·厦门北站',
#        '厦门·翔安区·火炬园', '厦门·思明区·轮渡', '厦门·思明区·厦门大学', '厦门·湖里区·高崎', '厦门·翔安区·马巷',
#        '厦门·思明区·会展中心', '厦门·思明区·莲坂', '厦门·集美区·印斗路', '厦门·集美区·侨英', '厦门·思明区·瑞景',
#        '厦门·集美区·华大', '厦门·集美区·大学康城', '厦门·思明区·莲前', '厦门·集美区', '厦门·海沧区',
#        '厦门·思明区·前埔', '厦门·思明区·松柏', '厦门·海沧区·东孚', '厦门·海沧区·海沧', '厦门·同安区·大同',
#        '厦门·思明区·嘉莲', '厦门·思明区·滨海', '厦门·湖里区·东渡', '厦门·湖里区·江头', '厦门·海沧区·石塘',
#        '厦门·思明区·斗西路', '厦门·翔安区·新店', '厦门·湖里区·塘边', '厦门·集美区·集美学村', '兰州',
#        '兰州·城关区·东湖', '兰州·城关区·火车站', '兰州·七里河区·秀川', '兰州·城关区·王府井',
#        '兰州·城关区·段家滩', '兰州·城关区·五泉', '兰州·安宁区·北滨河路', '兰州·安宁区·费家营',
#        '兰州·七里河区·兰州西站', '兰州·城关区·甘南路', '兰州·城关区·西关十字', '兰州·城关区·雁滩',
#        '兰州·七里河区·小西湖', '兰州·安宁区·西北师大', '兰州·城关区·兰州大学', '兰州·城关区·广武门',
#        '兰州·城关区·东岗东路', '兰州·城关区·天庆嘉园', '兰州·城关区·新港城', '兰州·安宁区·甘肃政法学院',
#        '兰州·城关区·张掖路', '兰州·安宁区·金牛街', '兰州·榆中县·榆中县中心城区', '兰州·七里河区·西津东路',
#        '兰州·城关区·大润发', '兰州·城关区·平凉路', '兰州·城关区·南关十字', '兰州·城关区·武都路',
#        '兰州·城关区·万达广场', '兰州·安宁区·交通大学', '兰州·城关区·北滨河路', '兰州·城关区·拱星墩',
#        '兰州·七里河区·西园村', '兰州·城关区·北面滩', '兰州·城关区·大砂坪', '兰州·城关区·酒泉路',
#        '兰州·西固区·福利路', '兰州·皋兰县·兰州新区', '兰州·城关区·东岗西路', '兰州·安宁区·十里店',
#        '兰州·城关区·静宁路', '兰州·城关区·滩尖子', '兰州·七里河区·龚家湾', '兰州·安宁区·培黎广场',
#        '兰州·西固区·西固人家', '兰州·安宁区·刘家堡'], dtype=object)

# %%
boss['职位地址'] = boss['职位地址'].apply(lambda x:x.split('·')[0])
boss['职位地址'].unique()
# Out:
# array(['北京', '深圳', '上海', '广州', '杭州', '天津', '西安', '厦门', '兰州'], dtype=object)

# %% [markdown]
# ### 3.5 经验列处理

# %%
boss['学历经验要求'].unique()
# Out:
# array(['3-5年学历不限', '3-5年大专', '5-10年本科', '经验不限学历不限', '3-5年本科', '1-3年本科',
#        '1-3年大专', '经验不限大专', '10年以上本科', '5天/周4个月本科', '5-10年大专', '1年以内本科',
#        '1-3年硕士', '1-3年初中及以下', '1-3年学历不限', '经验不限本科', '4天/周3个月本科',
#        '3天/周1个月硕士', '4天/周4个月本科', '5-10年学历不限', '5天/周6个月本科', '在校/应届学历不限',
#        '3天/周1个月本科', '在校/应届本科', '5-10年硕士', '经验不限博士', '5天/周3个月本科', '经验不限硕士',
#        '1年以内大专', '4天/周5个月本科', '1年以内硕士', '在校/应届硕士', '3-5年硕士', '4天/周4个月大专',
#        '4天/周6个月大专', '3天/周3个月大专', '6天/周12个月本科', '4天/周3个月硕士', '5天/周2个月大专',
#        '5天/周3个月大专', '5天/周12个月本科', '3天/周6个月学历不限', '在校/应届大专', '5天/周1个月大专',
#        '5天/周2个月本科', '5天/周3个月硕士', '5天/周6个月大专', '3天/周3个月本科', '5天/周4个月硕士',
#        '4天/周3个月学历不限', '4天/周1个月本科', '4天/周4个月硕士', '3天/周3个月硕士', '1年以内学历不限',
#        '4天/周6个月硕士', '3-5年高中', '4天/周6个月本科', '4天/周2个月本科', '3天/周2个月大专',
#        '3-5年初中及以下', '5天/周1个月本科', '在校/应届博士'], dtype=object)

# %%
boss['学历'] = boss['学历经验要求'].apply(lambda x:x[-2:])
boss.head()
# Out:
#               职位名称 职位地址          薪资    学历经验要求       公司名称              公司信息  \
# 0     Python 爬虫工程师   北京      20-40K  3-5年学历不限       墨云科技    信息安全B轮100-499人
# 1  底薪20K 双休 python   北京      20-21K    3-5年大专       惠承科技      企业服务100-499人
# 2     Python 开发工程师   北京  18-35K·14薪   5-10年本科  星云Clustar     互联网B轮100-499人
# 3   Python 后端开发工程师   北京      15-25K  经验不限学历不限     北京知道创宇  信息安全C轮1000-9999人
# 4     Python 开发工程师   北京  15-22K·14薪    3-5年本科       先胜业财    企业服务C轮100-499人
#
#                                                 公司福利  \
# 0         零食下午茶，餐补，定期体检，节日福利，年终奖，加班补助，五险一金，带薪年假，股票期权
# 1            年终奖，员工旅游，五险一金，节日福利，零食下午茶，定期体检，带薪年假，交通补助
# 2  交通补助，定期体检，餐补，年终奖，节日福利，零食下午茶，带薪年假，补充医疗保险，五险一金，股...
# 3  春节假期，通讯补贴，全勤奖，八险一金，年终奖，零食下午茶，补充医疗保险，节日福利，员工旅游，...
# 4  带薪年假，年终奖，节日福利，加班补助，股票期权，零食下午茶，通讯补贴，五险一金，定期体检，员工旅游
#
#                                                详情页链接  学历
# 0  https://www.zhipin.com/job_detail/3dd042791ae5...  不限
# 1  https://www.zhipin.com/job_detail/b845e2156d7e...  大专
# 2  https://www.zhipin.com/job_detail/43f73681f832...  本科
# 3  https://www.zhipin.com/job_detail/f7fe4279d46a...  不限
# 4  https://www.zhipin.com/job_detail/d8dcf215a266...  本科

# %%
import re
boss['经验'] = boss['学历经验要求'].apply(lambda x:x[:-2].replace('学历', '').replace('应届生', '经验不限').replace('在校/应届', '经验不限').replace('初中及', ''))
boss['经验'] = boss['经验'].apply(lambda x:re.sub('.*天/.*月', '1年以内', x))
boss.head()
# Out:
#               职位名称 职位地址          薪资    学历经验要求       公司名称              公司信息  \
# 0     Python 爬虫工程师   北京      20-40K  3-5年学历不限       墨云科技    信息安全B轮100-499人
# 1  底薪20K 双休 python   北京      20-21K    3-5年大专       惠承科技      企业服务100-499人
# 2     Python 开发工程师   北京  18-35K·14薪   5-10年本科  星云Clustar     互联网B轮100-499人
# 3   Python 后端开发工程师   北京      15-25K  经验不限学历不限     北京知道创宇  信息安全C轮1000-9999人
# 4     Python 开发工程师   北京  15-22K·14薪    3-5年本科       先胜业财    企业服务C轮100-499人
#
#                                                 公司福利  \
# 0         零食下午茶，餐补，定期体检，节日福利，年终奖，加班补助，五险一金，带薪年假，股票期权
# 1            年终奖，员工旅游，五险一金，节日福利，零食下午茶，定期体检，带薪年假，交通补助
# 2  交通补助，定期体检，餐补，年终奖，节日福利，零食下午茶，带薪年假，补充医疗保险，五险一金，股...
# 3  春节假期，通讯补贴，全勤奖，八险一金，年终奖，零食下午茶，补充医疗保险，节日福利，员工旅游，...
# 4  带薪年假，年终奖，节日福利，加班补助，股票期权，零食下午茶，通讯补贴，五险一金，定期体检，员工旅游
#
#                                                详情页链接  学历     经验
# 0  https://www.zhipin.com/job_detail/3dd042791ae5...  不限   3-5年
# 1  https://www.zhipin.com/job_detail/b845e2156d7e...  大专   3-5年
# 2  https://www.zhipin.com/job_detail/43f73681f832...  本科  5-10年
# 3  https://www.zhipin.com/job_detail/f7fe4279d46a...  不限   经验不限
# 4  https://www.zhipin.com/job_detail/d8dcf215a266...  本科   3-5年

# %%
boss['学历'].unique()
# Out:
# array(['不限', '大专', '本科', '硕士', '以下', '博士', '高中'], dtype=object)

# %%
boss['经验'].unique()
# Out:
# array(['3-5年', '5-10年', '经验不限', '1-3年', '10年以上', '1年以内'], dtype=object)

# %% [markdown]
# ### 3.7 薪资列处理

# %%
boss['薪资'] = boss['薪资'].apply(lambda x:re.sub('.*元/天', '4-6K', x))
boss['薪资'].unique()
# Out:
# array(['20-40K', '20-21K', '18-35K·14薪', '15-25K', '15-22K·14薪', '10-15K',
#        '12-18K', '13-26K', '15-25K·13薪', '15-30K', '13-18K', '20-30K·13薪',
#        '15-30K·13薪', '15-30K·14薪', '20-35K', '4-6K', '11-18K', '15-20K',
#        '15-20K·14薪', '12-20K', '8-13K', '20-40K·16薪', '10-15K·13薪',
#        '12-15K', '30-60K·15薪', '15-22K', '20-40K·14薪', '9-14K', '11-20K',
#        '13-20K·13薪', '16-25K·15薪', '20-35K·14薪', '14-28K', '8-10K',
#        '20-30K', '17-22K', '20-40K·15薪', '12-16K', '12-20K·13薪', '11-17K',
#        '8-9K', '16-30K·14薪', '15-16K', '25-40K', '4-8K', '12-24K·16薪',
#        '14-25K', '12-22K', '15-18K', '15-25K·14薪', '12-24K·13薪', '11-13K',
#        '30-50K·14薪', '7-12K·13薪', '9-14K·14薪', '20-25K·13薪', '13-25K',
#        '12-24K', '14-20K', '11-22K', '20-35K·13薪', '11-15K·13薪',
#        '17-22K·14薪', '13-20K', '10-14K', '12-16K·13薪', '12-17K',
#        '20-30K·14薪', '18-30K·16薪', '6-11K', '14-16K', '10-15K·14薪',
#        '25-50K·14薪', '5-7K', '25-50K·15薪', '21-25K', '2-4K', '18-35K·13薪',
#        '16-30K·13薪', '15-23K·13薪', '13-22K·15薪', '9-14K·15薪',
#        '18-30K·13薪', '15-20K·16薪', '11-15K', '13-18K·14薪', '11-20K·13薪',
#        '18-35K·15薪', '15-16K·13薪', '15-30K·15薪', '16-27K', '13-25K·13薪',
#        '25-35K', '16-18K', '25-50K', '18-19K·13薪', '17-30K', '18-26K',
#        '11-22K·13薪', '19-30K·14薪', '8-13K·13薪', '17-25K', '14-20K·13薪',
#        '14-21K', '28-50K·14薪', '15-19K·13薪', '3-6K', '8-12K',
#        '35-60K·16薪', '12-18K·13薪', '45-65K·14薪', '25-35K·14薪',
#        '14-22K·13薪', '14-22K', '10-11K·13薪', '15-30K·16薪', '7-12K',
#        '13-21K', '14-20K·14薪', '11-14K·13薪', '30-50K·13薪', '18-30K',
#        '40-60K·15薪', '3000-10000元/月', '5-10K·13薪', '40-65K·14薪', '6-10K',
#        '15-22K·13薪', '5-6K', '20-35K·15薪', '20-30K·16薪', '12-24K·14薪',
#        '30-60K', '17-30K·14薪', '3-7K', '26-50K', '15-23K', '13-17K',
#        '25-50K·16薪', '14-23K', '16-22K', '30-60K·16薪', '5-8K', '5-10K',
#        '6-7K', '12-17K·16薪', '11-22K·14薪', '9-13K', '18-28K·16薪',
#        '10-12K', '5-9K', '20-25K', '7-8K·13薪', '20-27K·15薪', '18-22K',
#        '13-16K', '18-20K', '16-20K', '25-40K·14薪', '40-70K·15薪',
#        '17-25K·13薪', '15-21K', '18-35K', '28-55K·15薪', '16-27K·14薪',
#        '6-9K', '20-40K·13薪', '15-26K·13薪', '6-8K', '35-55K·16薪', '11-19K',
#        '20-28K·13薪', '18-23K·13薪', '8-9K·14薪', '8-12K·13薪', '30-50K·16薪',
#        '16-25K·13薪', '25-40K·13薪', '15-18K·13薪', '12-20K·14薪',
#        '15-28K·13薪', '25-40K·15薪', '16-22K·16薪', '18-30K·15薪',
#        '25-35K·15薪', '15-17K', '12-22K·14薪', '11-20K·15薪', '15-26K',
#        '23-35K·13薪', '35-65K', '15-20K·13薪', '5-8K·13薪', '15-18K·14薪',
#        '35-65K·16薪', '13-21K·16薪', '18-25K', '15-27K', '50-80K',
#        '13-26K·13薪', '7-10K', '11-16K·16薪', '16-19K', '50-80K·16薪',
#        '1-2K', '16-30K', '3-4K', '13-25K·14薪', '16-25K', '13-18K·13薪',
#        '6-10K·13薪', '9-12K', '13-22K', '11-16K·13薪', '12-15K·13薪',
#        '12-17K·13薪', '25-35K·13薪', '30-60K·14薪', '6-11K·13薪',
#        '30-45K·15薪', '20-25K·14薪', '14-16K·13薪', '10-15K·15薪',
#        '12-17K·14薪', '8-15K·13薪', '11-20K·14薪', '18-35K·16薪',
#        '10-14K·13薪', '18-30K·14薪', '11-16K', '7-9K', '10-11K', '14-24K',
#        '8-15K', '12-19K', '13-23K', '3-8K', '14-18K', '14-21K·16薪',
#        '17-30K·13薪', '8-11K', '12-21K·13薪', '17-23K', '13-19K',
#        '12-22K·13薪', '9-14K·13薪', '17-21K', '22-40K·14薪', '14-22K·14薪',
#        '11-18K·14薪', '13-26K·15薪', '10-13K', '16-21K', '15-25K·15薪',
#        '8-13K·14薪', '22-30K', '30-40K·13薪', '12-16K·16薪', '20-35K·16薪',
#        '15-26K·16薪', '14-28K·13薪', '25-30K·13薪', '19-35K·15薪',
#        '13-26K·14薪', '10-20K', '4-7K·13薪', '8-12K·14薪', '7-12K·14薪',
#        '11-18K·13薪', '30-40K·14薪', '12-24K·15薪', '9-11K·13薪',
#        '15-17K·13薪', '6-9K·13薪', '18-25K·14薪', '15-30K·18薪', '11-20K·16薪',
#        '15-28K', '20-40K·18薪', '18-22K·14薪', '25-45K', '21-35K·15薪',
#        '16-17K', '14-15K', '18-25K·13薪', '8-12K·15薪', '12-20K·16薪',
#        '14-25K·14薪', '8-10K·13薪', '22-23K·13薪', '8-11K·13薪', '23-30K·16薪',
#        '23-45K', '4-9K', '12-15K·14薪', '15-22K·16薪', '2-7K', '15-16K·24薪',
#        '12-20K·15薪', '4-7K', '4-9K·13薪', '18-28K·13薪', '6-7K·13薪',
#        '16-28K', '5-8K·14薪', '4-8K·13薪', '2-3K', '3-5K·13薪', '16-24K',
#        '6-10K·14薪', '7-8K', '5-10K·14薪', '27-45K·16薪', '22-40K',
#        '15-22K·15薪', '3-5K', '11-17K·13薪', '10-15K·16薪', '7-11K·14薪',
#        '16-25K·14薪', '13-18K·15薪', '15-25K·16薪', '12-23K·14薪',
#        '17-25K·14薪', '11-21K', '18-28K', '12-14K', '12-21K', '16-30K·16薪',
#        '13-26K·16薪', '20-25K·16薪', '14-28K·14薪', '10-40K·15薪', '16-26K',
#        '3-8K·13薪', '5-7K·13薪', '10-12K·13薪', '7-11K·13薪', '9-13K·14薪',
#        '13-22K·13薪', '12-13K', '4-8K·14薪', '9-10K', '4-6K·13薪',
#        '3-6K·13薪', '14-25K·15薪', '4000-8000元/月', '6-8K·13薪', '16-20K·14薪',
#        '11-15K·14薪', '9-13K·13薪', '7-11K', '3-7K·13薪', '13-20K·14薪',
#        '25-45K·16薪', '12-18K·14薪', '4-5K', '11-22K·17薪', '13-16K·13薪',
#        '13-14K·16薪', '8-12K·16薪', '10-14K·14薪', '9-12K·14薪',
#        '1000-2000元/月', '6-12K', '7-10K·15薪', '14-15K·13薪', '8-13K·15薪',
#        '8-12K·18薪', '12-18K·15薪', '13-15K·13薪', '8-13K·17薪', '15-19K',
#        '11-12K'], dtype=object)

# %%
boss['bottom'] = boss['薪资'].str.extract('^(.*?)-.*?')
boss['top'] = boss['薪资'].str.extract('^.*?-(\d\d\.\d|\d\d)')

# %%
boss['bottom'] = boss['bottom'].astype('float64')
boss['top'] = boss['top'].astype('float64')

# %%
boss['工资平均'] = (boss['bottom']+boss['top'])/2

# %%
boss.head()
# Out:
#               职位名称 职位地址          薪资    学历经验要求       公司名称              公司信息  \
# 0     Python 爬虫工程师   北京      20-40K  3-5年学历不限       墨云科技    信息安全B轮100-499人
# 1  底薪20K 双休 python   北京      20-21K    3-5年大专       惠承科技      企业服务100-499人
# 2     Python 开发工程师   北京  18-35K·14薪   5-10年本科  星云Clustar     互联网B轮100-499人
# 3   Python 后端开发工程师   北京      15-25K  经验不限学历不限     北京知道创宇  信息安全C轮1000-9999人
# 4     Python 开发工程师   北京  15-22K·14薪    3-5年本科       先胜业财    企业服务C轮100-499人
#
#                                                 公司福利  \
# 0         零食下午茶，餐补，定期体检，节日福利，年终奖，加班补助，五险一金，带薪年假，股票期权
# 1            年终奖，员工旅游，五险一金，节日福利，零食下午茶，定期体检，带薪年假，交通补助
# 2  交通补助，定期体检，餐补，年终奖，节日福利，零食下午茶，带薪年假，补充医疗保险，五险一金，股...
# 3  春节假期，通讯补贴，全勤奖，八险一金，年终奖，零食下午茶，补充医疗保险，节日福利，员工旅游，...
# 4  带薪年假，年终奖，节日福利，加班补助，股票期权，零食下午茶，通讯补贴，五险一金，定期体检，员工旅游
#
#                                                详情页链接  学历     经验  bottom   top  \
# 0  https://www.zhipin.com/job_detail/3dd042791ae5...  不限   3-5年    20.0  40.0
# 1  https://www.zhipin.com/job_detail/b845e2156d7e...  大专   3-5年    20.0  21.0
# 2  https://www.zhipin.com/job_detail/43f73681f832...  本科  5-10年    18.0  35.0
# 3  https://www.zhipin.com/job_detail/f7fe4279d46a...  不限   经验不限    15.0  25.0
# 4  https://www.zhipin.com/job_detail/d8dcf215a266...  本科   3-5年    15.0  22.0
#
#    工资平均
# 0  30.0
# 1  20.5
# 2  26.5
# 3  20.0
# 4  18.5

# %% [markdown]
# ## 4.数据分析（数据可视化）

# %% [markdown]
# 薪资 区间 经验要求 情况 学历要求 情况 什么地区招聘人员比较多的 经验要求 和 薪资情况的情况 是不是薪资越高 经验要求越高 学历要求 和 薪资情况的情况 是不是薪资越高 学历要求越高

# %% [markdown]
# ### 4.1 薪资区间

# %%
def tranform_price(x):
    if x <= 8.0:
        return '6k以下'
    elif x <= 12:
        return '8-12k'
    elif x <= 15.0:
        return '12k-15k'
    elif x <= 20:
        return '15-20k'
    elif x <= 25:
        return '20-25k'
    else:
        return '25k以上'

# %%
boss['薪资分级'] = boss['工资平均'].apply(lambda x:tranform_price(x))
price_1 = boss['薪资分级'].value_counts()
datas_pair_1 = [(i, int(j)) for i, j in zip(price_1.index, price_1.values)]
datas_pair_1
# Out:
# [('15-20k', 572),
#  ('25k以上', 497),
#  ('8-12k', 396),
#  ('12k-15k', 381),
#  ('20-25k', 357),
#  ('6k以下', 105)]

# %%
pie1 = (
    Pie(init_opts=opts.InitOpts(theme='dark',width='1000px',height='600px'))
    
    .add('', datas_pair_1, radius=['35%', '60%'])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{d}%"))
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="python职位\n\n薪资区间", 
            pos_left='center', 
            pos_top='center',
            title_textstyle_opts=opts.TextStyleOpts(
                color='#F0F8FF', 
                font_size=20, 
                font_weight='bold'
            ),
        )
    )
    .set_colors(['#EF9050', '#3B7BA9', '#6FB27C', '#FFAF34', '#D8BFD8', '#00BFFF', '#7FFFAA'])
)
pie1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="53b177bc78bd4f86bacb993813378f73" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_53b177bc78bd4f86bacb993813378f73 = echarts.init(
#                     document.getElementById('53b177bc78bd4f86bacb993813378f73'), 'dark', {renderer: 'canvas'});
#                 var option_53b177bc78bd4f86bacb993813378f73 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "15-20k",
#                     "value": 572
#                 },
#                 {
#                     "name": "25k\u4ee5\u4e0a",
#                     "value": 497
#                 },
#                 {
#                     "name": "8-12k",
#                     "value": 396
#                 },
#                 {
#                     "name": "12k-15k",
#                     "value": 381
#                 },
#                 {
#                     "name": "20-25k",
#                     "value": 357
#                 },
#                 {
#                     "name": "6k\u4ee5\u4e0b",
#                     "value": 105
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}:{d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "15-20k",
#                 "25k\u4ee5\u4e0a",
#                 "8-12k",
#                 "12k-15k",
#                 "20-25k",
#                 "6k\u4ee5\u4e0b"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "python\u804c\u4f4d\n\n\u85aa\u8d44\u533a\u95f4",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "top": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "color": "#F0F8FF",
#                 "fontWeight": "bold",
#                 "fontSize": 20
#             }
#         }
#     ],
#     "color": [
#         "#EF9050",
#         "#3B7BA9",
#         "#6FB27C",
#         "#FFAF34",
#         "#D8BFD8",
#         "#00BFFF",
#         "#7FFFAA"
#     ]
# };
#                 chart_53b177bc78bd4f86bacb993813378f73.setOption(option_53b177bc78bd4f86bacb993813378f73);
#         });
#     </script>

# %% [markdown]
# ### 4.2 经验、学历要求情况

# %%
boss_1 = boss['经验'].value_counts()
x = boss_1.index.tolist()
y = boss_1.values.tolist()
boss_2 = boss['学历'].value_counts()
x_2 = boss_2.index.tolist()
y_2 = boss_2.values.tolist()
data_pair_1 = [list(z) for z in zip(x, y)]
data_pair_2 = [list(z) for z in zip(x_2, y_2)]

# %%
c = (
    Pie(init_opts=opts.InitOpts(width="1000px", height="600px", bg_color="#2c343c"))
    .add(
        series_name="经验需求占比",
        data_pair=data_pair_1,
        rosetype="radius",
        radius="55%",
        center=["25%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center", color="rgba(255, 255, 255, 0.3)"),
    )
    .add(
        series_name="学历需求占比",
        data_pair=data_pair_2,
        
        radius="55%",
        center=["75%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center", color="rgba(255, 255, 255, 0.3)"),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(color="rgba(255, 255, 255, 0.3)"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="经验、学历需求占比",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_colors(["#D53A35", "#334B5C", "#61A0A8", "#D48265", "#749F83"])
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4198df44d3b74224bab76ba13118dd35" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4198df44d3b74224bab76ba13118dd35 = echarts.init(
#                     document.getElementById('4198df44d3b74224bab76ba13118dd35'), 'white', {renderer: 'canvas'});
#                 var option_4198df44d3b74224bab76ba13118dd35 = {
#     "backgroundColor": "#2c343c",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#D53A35",
#         "#334B5C",
#         "#61A0A8",
#         "#D48265",
#         "#749F83"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u7ecf\u9a8c\u9700\u6c42\u5360\u6bd4",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 806
#                 },
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 694
#                 },
#                 {
#                     "name": "\u7ecf\u9a8c\u4e0d\u9650",
#                     "value": 525
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 143
#                 },
#                 {
#                     "name": "1\u5e74\u4ee5\u5185",
#                     "value": 139
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 1
#                 }
#             ],
#             "radius": "55%",
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "color": "rgba(255, 255, 255, 0.3)",
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": "\u5b66\u5386\u9700\u6c42\u5360\u6bd4",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 1695
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 460
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u4ee5\u4e0b",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u535a\u58eb",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9ad8\u4e2d",
#                     "value": 1
#                 }
#             ],
#             "radius": "55%",
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "color": "rgba(255, 255, 255, 0.3)",
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-3\u5e74",
#                 "3-5\u5e74",
#                 "\u7ecf\u9a8c\u4e0d\u9650",
#                 "5-10\u5e74",
#                 "1\u5e74\u4ee5\u5185",
#                 "10\u5e74\u4ee5\u4e0a",
#                 "\u672c\u79d1",
#                 "\u5927\u4e13",
#                 "\u4e0d\u9650",
#                 "\u7855\u58eb",
#                 "\u4ee5\u4e0b",
#                 "\u535a\u58eb",
#                 "\u9ad8\u4e2d"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,

# %% [markdown]
# ### 4.4 经验要求 和 薪资情况的情况 是不是薪资越高 经验要求越高

# %%
mean = boss.groupby('经验')['工资平均'].mean().sort_values()
x = mean.index.tolist()
y = mean.values.tolist()
c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis(
        "工作经验",
        y,
        markpoint_opts=opts.MarkPointOpts(
            data=[opts.MarkPointItem(name="3-5年经验", coord=[x[3], y[3]], value=y[3])]
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="不同工作经验的平均薪资"))
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="51e1491af7a44af1b09dbb063eb2f5ce" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_51e1491af7a44af1b09dbb063eb2f5ce = echarts.init(
#                     document.getElementById('51e1491af7a44af1b09dbb063eb2f5ce'), 'white', {renderer: 'canvas'});
#                 var option_51e1491af7a44af1b09dbb063eb2f5ce = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de5\u4f5c\u7ecf\u9a8c",
#             "legendHoverLink": true,
#             "data": [
#                 14.041666666666666,
#                 16.493036211699163,
#                 19.06413994169096,
#                 23.17142857142857,
#                 23.261111111111113,
#                 25.0
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "3-5\u5e74\u7ecf\u9a8c",
#                         "coord": [
#                             "5-10\u5e74",
#                             23.17142857142857
#                         ],
#                         "value": 23.17142857142857
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4f5c\u7ecf\u9a8c"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u5e74\u4ee5\u5185",
#                 "1-3\u5e74",
#                 "3-5\u5e74",
#                 "5-10\u5e74",
#                 "\u7ecf\u9a8c\u4e0d\u9650",
#                 "10\u5e74\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5de5\u4f5c\u7ecf\u9a8c\u7684\u5e73\u5747\u85aa\u8d44",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_51e1491af7a44af1b09dbb063eb2f5ce.setOption(option_51e1491af7a44af1b09dbb063eb2f5ce);
#         });
#     </script>

# %% [markdown]
# ### 4.5 学历要求 和 薪资情况的情况 是不是薪资越高 学历要求越高

# %%
mean = boss.groupby('学历')['工资平均'].mean().sort_values()
x = mean.index.tolist()
y = mean.values.tolist()
c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis(
        "学历",
        y,
        markpoint_opts=opts.MarkPointOpts(
            data=[opts.MarkPointItem(name="学历不限", coord=[x[1], y[1]], value=y[1])]
        )
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="不同学历的平均薪资"))
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2203f6889f884f449abb19a4d49a50c9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2203f6889f884f449abb19a4d49a50c9 = echarts.init(
#                     document.getElementById('2203f6889f884f449abb19a4d49a50c9'), 'white', {renderer: 'canvas'});
#                 var option_2203f6889f884f449abb19a4d49a50c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5b66\u5386",
#             "legendHoverLink": true,
#             "data": [
#                 15.0,
#                 15.82642487046632,
#                 16.93103448275862,
#                 17.5,
#                 19.380670611439843,
#                 21.5,
#                 33.233333333333334
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5b66\u5386\u4e0d\u9650",
#                         "coord": [
#                             "\u5927\u4e13",
#                             15.82642487046632
#                         ],
#                         "value": 15.82642487046632
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b66\u5386"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9ad8\u4e2d",
#                 "\u5927\u4e13",
#                 "\u7855\u58eb",
#                 "\u535a\u58eb",
#                 "\u672c\u79d1",
#                 "\u4ee5\u4e0b",
#                 "\u4e0d\u9650"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5b66\u5386\u7684\u5e73\u5747\u85aa\u8d44",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_2203f6889f884f449abb19a4d49a50c9.setOption(option_2203f6889f884f449abb19a4d49a50c9);
#         });
#     </script>

# %%
text = boss['公司福利'].dropna().to_string()
text
import jieba
words = jieba.lcut(text)
#通过遍历words的方式,统计出每个词出现的频次
counts = {}
for word in words:
    if len(word) == 1:
        continue
    else:
        counts[word] = counts.get(word,0) + 1
items = list(counts.items())
new = []
for i in items:
    if i[1] > 3:
        new.append(i)
c = (
    WordCloud()
    .add(series_name="热点分析", data_pair=new, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="公司福利", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
)
c.render_notebook()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\24613\AppData\Local\Temp\jieba.cache
# Loading model cost 0.495 seconds.
# Prefix dict has been built successfully.
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ec9d986cc6db450ba7d68088a77a5e47" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ec9d986cc6db450ba7d68088a77a5e47 = echarts.init(
#                     document.getElementById('ec9d986cc6db450ba7d68088a77a5e47'), 'white', {renderer: 'canvas'});
#                 var option_ec9d986cc6db450ba7d68088a77a5e47 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u96f6\u98df",
#                     "value": 1126,
#                     "textStyle": {
#                         "color": "rgb(64,61,68)"
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u5348\u8336",
#                     "value": 1110,
#                     "textStyle": {
#                         "color": "rgb(80,35,23)"
#                     }
#                 },
#                 {
#                     "name": "\u9910\u8865",
#                     "value": 876,
#                     "textStyle": {
#                         "color": "rgb(125,60,72)"
#                     }
#                 },
#                 {
#                     "name": "\u5b9a\u671f",
#                     "value": 1252,
#                     "textStyle": {
#                         "color": "rgb(141,27,22)"
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u68c0",
#                     "value": 1219,
#                     "textStyle": {
#                         "color": "rgb(7,13,115)"
#                     }
#                 },
#                 {
#                     "name": "\u8282\u65e5",
#                     "value": 1592,
#                     "textStyle": {
#                         "color": "rgb(31,89,116)"
#                     }
#                 },
#                 {
#                     "name": "\u798f\u5229",
#                     "value": 1635,
#                     "textStyle": {
#                         "color": "rgb(120,152,59)"
#                     }
#                 },
#                 {
#                     "name": "\u5e74\u7ec8\u5956",
#                     "value": 1523,
#                     "textStyle": {
#                         "color": "rgb(54,146,5)"
#                     }
#                 },
#                 {
#                     "name": "\u52a0\u73ed",
#                     "value": 801,
#                     "textStyle": {
#                         "color": "rgb(35,95,146)"
#                     }
#                 },
#                 {
#                     "name": "\u8865\u52a9",
#                     "value": 1339,
#                     "textStyle": {
#                         "color": "rgb(133,122,141)"
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u9669",
#                     "value": 1865,
#                     "textStyle": {
#                         "color": "rgb(74,82,34)"
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u91d1",
#                     "value": 1848,
#                     "textStyle": {
#                         "color": "rgb(84,27,125)"
#                     }
#                 },
#                 {
#                     "name": "\u5e26\u85aa",
#                     "value": 1590,
#                     "textStyle": {
#                         "color": "rgb(99,134,30)"
#                     }
#                 },
#                 {
#                     "name": "\u80a1\u7968",
#                     "value": 735,
#                     "textStyle": {
#                         "color": "rgb(6,38,81)"
#                     }
#                 },
#                 {
#                     "name": "\u671f\u6743",
#                     "value": 727,
#                     "textStyle": {
#                         "color": "rgb(41,89,104)"
#                     }
#                 },
#                 {
#                     "name": "\u5458\u5de5",
#                     "value": 1162,
#                     "textStyle": {
#                         "color": "rgb(35,10,74)"
#                     }
#                 },
#                 {
#                     "name": "\u65c5\u6e38",
#                     "value": 1126,
#                     "textStyle": {
#                         "color": "rgb(44,121,67)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 570,
#                     "textStyle": {
#                         "color": "rgb(97,99,70)"
#                     }
#                 },
#                 {
#                     "name": "\u8865\u5145",
#                     "value": 710,
#                     "textStyle": {
#                         "color": "rgb(16,111,110)"
#                     }
#                 },
#                 {
#                     "name": "\u533b\u7597\u4fdd\u9669",
#                     "value": 683,
#                     "textStyle": {
#                         "color": "rgb(149,112,89)"
#                     }
#                 },
#                 {
#                     "name": "...",
#                     "value": 498,
#                     "textStyle": {
#                         "color": "rgb(152,150,117)"
#                     }
#                 },
#                 {
#                     "name": "\u901a\u8baf",
#                     "value": 521,
#                     "textStyle": {
#                         "color": "rgb(118,27,7)"
#                     }
#                 },
#                 {
#                     "name": "\u8865\u8d34",
#                     "value": 532,
#                     "textStyle": {
#                         "color": "rgb(69,97,1)"
#                     }
#                 },
#                 {
#                     "name": "\u5168\u52e4\u5956",
#                     "value": 449,
#                     "textStyle": {
#                         "color": "rgb(19,43,33)"
#                     }
#                 },
#                 {
#                     "name": "\u5de5\u4f5c",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(29,140,42)"
#                     }
#                 },
#                 {
#                     "name": "\u6c1b\u56f4",
#                     "value": 5,
#                     "textStyle": {
#                         "color": "rgb(110,148,126)"
#                     }
#                 },
#                 {
#                     "name": "\u514d\u8d39",
#                     "value": 338,
#                     "textStyle": {
#                         "color": "rgb(72,27,110)"
#                     }
#                 },
#                 {
#                     "name": "\u73ed\u8f66",
#                     "value": 297,
#                     "textStyle": {
#                         "color": "rgb(133,64,160)"
#                     }
#                 },
#                 {
#                     "name": "11",
#                     "value": 4,
#                     "textStyle": {
#                         "color": "rgb(66,144,94)"
#                     }
#                 },
